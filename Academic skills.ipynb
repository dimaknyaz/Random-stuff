# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\Dima\Downloads\Vegetariansm, Germany.csv")
df1 = pd.read_csv(r"C:\Users\Dima\Downloads\Veganism, Germany.csv")

def read_vegans(country):
    df=pd.read_csv(r"C:\Users\Dima\Downloads\Veganism, "+ country + ".csv")
    return df
def read_vegetarians(country):
    df=pd.read_csv(r"C:\Users\Dima\Downloads\Vegetarianism, "+ country + ".csv")
    return df

# %%
BG_vegans = read_vegans('BG')
DK_vegans = read_vegans('DK')
NL_vegans = read_vegans('NL')
AU_vegans = read_vegans('AU')
BG_vegetarians = read_vegetarians('BG')
DK_vegetarians = read_vegetarians('DK')
NL_vegetarians = read_vegetarians('NL')
AU_vegetarians = read_vegetarians('AU')

# %%
def get_values(df):
    values = [df["Category: All categories"][i] for i in range(len(df))]
    int_values = [int(i) for i in values[1:]]
    return int_values

# %%
int_values = [int(i) for i in values[1:]]
int_values_veganism = [int(i) for i in values_veganism[1:]]

# %%
from matplotlib.pyplot import figure
def plot(vegans,vegetarians, country):
    figure(num=None, figsize=(12, 6), dpi=80, facecolor='w', edgecolor='k')
    plt.plot(range(len(vegetarians)), vegetarians, label = 'Vegetarians')
    plt.plot(range(len(vegans)), vegans, label = 'Vegans')
    plt.legend()
    plt.title(country)
    plt.xlabel("Time in weeks")
    plt.ylabel("Relative frequency")
    plt.show()
    return()

plot(int_values_veganism,int_values, 'Germany' )
# Out:
# ()

# %%
plot(get_values(NL_vegans), get_values(NL_vegetarians), "Netherlands")
plot(get_values(DK_vegans), get_values(DK_vegetarians), "Denmark")
plot(get_values(BG_vegans), get_values(BG_vegetarians), "Belgium")
plot(get_values(AU_vegans), get_values(AU_vegetarians), "Austria")
# Out:
# ()

# %%
ratios = [int_values[i]/int_values_veganism[i] for i in range(len(df)-1)]
figure(num=None, figsize=(12, 6), dpi=80, facecolor='w', edgecolor='k')
axes = plt.gca()
#axes.set_xlim([xmin,xmax])
axes.set_ylim([0,1.5])
plt.plot(range(len(ratios)), ratios, label = 'Vegetarians/Vegans')
plt.xlabel("Time in weeks")
plt.ylabel("ratio of frequences")
plt.title('Germany')
plt.show()

# %%
trends = pd.read_csv(r"C:\Users\Dima\Downloads\Passport_Stats_06-03-2021_1441_GMT.csv")
trends.describe()
# Out:
#        Unnamed: 0             Unnamed: 1                 Unnamed: 2  \
# count          17                     11                         11
# unique         12                      3                          2
# top       Denmark  Vegetarian Population  Socio-economic indicators
# freq            2                      5                         10
#
#        Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# count          11         11         11         11         11         11
# unique          2          2         11         11         11         11
# top           000          -        117     82,176      5,749     82,792
# freq           10         10          1          1          1          1
#
#        Unnamed: 9 Unnamed: 10
# count          11          11
# unique         11          11
# top           244      83,167
# freq            1           1

# %%
AU = [796/8701, 806/8773,814/8822, 822/8878, 831/8901] 
BG = [225/11268,233/11322,238/11376,244/11431,245/11493]
DK = [114/5707,104/5749,139/5781,145/5806,149/5823]
GM = [7396/82176,7427/82522,8279/82792,8543/83019,8786/83167]
NL = [801/16901,820/17082,841/17181,864/17282,881/17408]
x = [2016,2017,2018,2019,2020]

# %%
figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
plt.plot(x, AU, label = 'Austria')
plt.plot(x, BG, label = 'Belgium')
plt.plot(x, GM, label = 'Germany')
plt.plot(x, DK, label = 'Denmark')
plt.plot(x, NL, label = 'Netherlands')
plt.xticks(x,x)
plt.legend()
plt.title('Vegetarian share of population')
plt.xlabel("Time, years")
plt.ylabel("Share of vegetarians")
plt.show()

# %%
figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
plt.scatter(x, AU, label = 'Austria')
plt.scatter(x, BG, label = 'Belgium')
plt.scatter(x, GM, label = 'Germany')
plt.scatter(x, DK, label = 'Denmark')
plt.scatter(x, NL, label = 'Netherlands')
plt.xticks(x,x)
plt.legend()
plt.title('Vegetarian share of population')
plt.xlabel("Time, years")
plt.ylabel("Share of vegetarians")
plt.show()
